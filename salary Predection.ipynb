# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset3/main/Salaries.csv")
data.head()
# Out:
#        rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0      Prof          B             19           18  Male  139750
# 1      Prof          B             20           16  Male  173200
# 2  AsstProf          B              4            3  Male   79750
# 3      Prof          B             45           39  Male  115000
# 4      Prof          B             40           41  Male  141500

# %%
data.head()
# Out:
#        rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0      Prof          B             19           18  Male  139750
# 1      Prof          B             20           16  Male  173200
# 2  AsstProf          B              4            3  Male   79750
# 3      Prof          B             45           39  Male  115000
# 4      Prof          B             40           41  Male  141500

# %%
data.tail(2)
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035

# %%
data.sample()
# Out:
#     rank discipline  yrs.since.phd  yrs.service   sex  salary
# 32  Prof          B             13            9  Male  117256

# %%
data.columns
# Out:
# Index(['rank', 'discipline', 'yrs.since.phd', 'yrs.service', 'sex', 'salary'], dtype='object')

# %%
data.shape
# Out:
# (397, 6)

# %%
data.describe()
# Out:
#        yrs.since.phd  yrs.service         salary
# count     397.000000   397.000000     397.000000
# mean       22.314861    17.614610  113706.458438
# std        12.887003    13.006024   30289.038695
# min         1.000000     0.000000   57800.000000
# 25%        12.000000     7.000000   91000.000000
# 50%        21.000000    16.000000  107300.000000
# 75%        32.000000    27.000000  134185.000000
# max        56.000000    60.000000  231545.000000

# %%
data = data.drop(columns = ['rank','discipline','sex'])
data.head()
# Out:
#    yrs.since.phd  yrs.service  salary
# 0             19           18  139750
# 1             20           16  173200
# 2              4            3   79750
# 3             45           39  115000
# 4             40           41  141500

# %%
plt.figure(figsize=(15,10), facecolor='red')
plotnumber = 1

for column in data:
    if plotnumber<=8:
        ax = plt.subplot(1,3,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column, fontsize = 20)
    
    plotnumber+=1
plt.tight_layout()

# %%
y = data['salary']
x = data.drop(columns = ['salary'])
y
# Out:
# 0      139750
# 1      173200
# 2       79750
# 3      115000
# 4      141500
#         ...
# 392    103106
# 393    150564
# 394    101738
# 395     95329
# 396     81035
# Name: salary, Length: 397, dtype: int64

# %%
x
# Out:
#      yrs.since.phd  yrs.service
# 0               19           18
# 1               20           16
# 2                4            3
# 3               45           39
# 4               40           41
# ..             ...          ...
# 392             33           30
# 393             31           19
# 394             42           25
# 395             25           15
# 396              8            4
#
# [397 rows x 2 columns]

# %%
scaler= StandardScaler()
x_scaled = scaler.fit_transform(x)
x_scaled
# Out:
# array([[-0.25754973,  0.02966908],
#        [-0.17985426, -0.12429986],
#        [-1.42298184, -1.12509795],
#        [ 1.76253259,  1.64634292],
#        [ 1.37405522,  1.80031186],
#        [-1.26759089, -0.89414455],
#        [ 0.59710048,  0.41459142],
#        [ 1.76253259,  2.10824973],
#        [-0.10215878,  0.18363801],
#        [-0.33524521,  0.02966908],
#        [-0.80141805, -0.74017561],
#        [-1.18989542, -1.20208242],
#        [-1.65606826, -1.27906689],
#        [-1.57837279, -1.35605136],
#        [-0.17985426,  0.02966908],
#        [-0.80141805, -1.12509795],
#        [-0.25754973,  0.18363801],
#        [ 1.21866427,  1.26142058],
#        [ 1.1409688 ,  0.41459142],
#        [ 1.29635975,  1.41538951],
#        [ 0.67479596,  0.64554483],
#        [ 1.06327332,  1.03046717],
#        [ 0.90788238,  0.9534827 ],
#        [ 0.13092764,  0.10665355],
#        [-0.72372258, -0.74017561],
#        [-0.10215878, -0.74017561],
#        [ 0.98557785,  0.41459142],
#        [-1.34528637, -1.12509795],
#        [-0.87911352, -1.35605136],
#        [-0.80141805, -0.74017561],
#        [-0.17985426, -1.04811348],
#        [-1.18989542, -1.20208242],
#        [-0.72372258, -0.66319114],
#        [-1.42298184, -1.20208242],
#        [-1.42298184, -1.20208242],
#        [-1.34528637, -1.35605136],
#        [-0.02446331,  0.26062248],
#        [-1.18989542, -1.04811348],
#        [ 1.45175069,  1.03046717],
#        [-1.03450447, -0.66319114],
#        [ 0.05323216, -1.20208242],
#        [ 0.05323216,  0.41459142],
#        [ 1.37405522,  0.7225293 ],
#        [ 1.21866427,  1.56935845],
#        [-0.25754973,  0.10665355],
#        [ 0.20862311, -0.20128433],
#        [ 1.37405522,  0.79951376],
#        [ 0.05323216,  0.10665355],
#        [ 0.20862311,  0.56856036],
#        [-1.65606826, -1.27906689],
#        [ 0.44170953,  0.79951376],
#        [-0.80141805, -0.5092222 ],
#        [-0.87911352, -1.12509795],
#        [-0.49063615, -0.66319114],
#        [-0.80141805, -0.5092222 ],
#        [-0.6460271 , -0.97112901],
#        [ 0.05323216,  0.26062248],
#        [-1.03450447, -0.74017561],
#        [-0.956809  , -0.66319114],
#        [-1.11219995, -1.12509795],
#        [-1.03450447, -0.74017561],
#        [-1.50067732, -1.20208242],
#        [ 0.8301869 ,  1.03046717],
#        [-0.87911352, -0.5092222 ],
#        [-1.42298184, -1.12509795],
#        [-1.03450447, -0.74017561],
#        [-0.02446331, -0.43223773],
#        [ 0.98557785,  1.03046717],
#        [-0.41294068, -0.04731539],
#        [ 0.44170953,  1.41538951],
#        [-0.41294068, -1.20208242],
#        [ 1.76253259,  2.10824973],
#        [ 0.51940501,  0.10665355],
#        [ 0.98557785,  1.26142058],
#        [ 0.44170953,  0.41459142],
#        [-1.11219995, -1.12509795],
#        [-0.41294068, -1.12509795],
#        [ 0.28631859,  0.10665355],
#        [-1.50067732, -1.27906689],
#        [-1.26759089, -1.20208242],
#        [ 1.60714164,  0.79951376],
#        [-0.41294068, -0.12429986],
#        [-0.02446331,  0.18363801],
#        [-1.26759089, -1.20208242],
#        [-0.41294068,  0.02966908],
#        [-0.56833163, -0.2782688 ],
#        [ 1.1409688 ,  1.49237398],
#        [-1.57837279, -1.20208242],
#        [ 0.20862311,  0.56856036],
#        [-1.03450447, -0.81716008],
#        [-0.956809  , -0.97112901],
#        [-0.956809  , -0.81716008],
#        [-0.956809  , -0.81716008],
#        [ 1.21866427,  1.56935845],
#        [-0.10215878,  0.18363801],
#        [-1.42298184, -1.35605136],
#        [-0.41294068, -0.43223773],
#        [-0.72372258, -0.81716008],
#        [ 0.59710048, -0.2782688 ],
#        [ 1.45175069,  0.64554483],
#        [ 1.52944617,  0.56856036],
#        [ 0.44170953,  0.41459142],
#        [-0.49063615, -0.97112901],
#        [-0.17985426, -0.2782688 ],
#        [-0.33524521, -0.58620667],
#        [ 0.67479596,  0.79951376],
#        [-0.87911352, -0.74017561],
#        [-0.956809  , -0.74017561],
#        [-0.56833163, -0.74017561],
#        [ 1.37405522,  1.03046717],
#        [-0.17985426, -0.12429986],
#        [-0.25754973, -0.12429986],
#        [-1.50067732, -1.27906689],
#        [ 1.1409688 ,  1.49237398],
#        [-0.80141805, -1.35605136],
#        [-0.10215878, -0.66319114],
#        [ 0.59710048,  0.87649823],
#        [ 1.29635975,  1.41538951],
#        [-1.42298184, -1.27906689],
#        [-1.34528637, -1.12509795],
#        [-0.6460271 , -0.2782688 ],
#        [ 0.75249143,  1.10745164],
#        [ 0.13092764,  0.33760695],
#        [ 0.20862311,  0.33760695],
#        [ 0.13092764,  0.33760695],
#        [ 2.46179186,  2.4161876 ],
#        [ 0.44170953,  0.64554483],
#        [-1.57837279, -1.35605136],
#        [ 0.75249143,  0.9534827 ],
#        [-1.42298184, -1.20208242],
#        [-0.87911352, -0.66319114],
#        [ 2.6171828 ,  3.03206335],
#        [-0.956809  , -0.74017561],
#        [-1.50067732, -1.27906689],
#        [ 0.98557785,  0.56856036],
#        [-0.17985426,  0.02966908],
#        [-0.49063615, -0.2782688 ],
#        [-0.41294068, -0.2782688 ],
#        [-0.956809  , -0.81716008],
#        [-0.10215878,  0.02966908],
#        [-0.6460271 , -0.74017561],
#        [-0.56833163, -0.58620667],
#        [-0.25754973, -0.5092222 ],
#        [-1.50067732, -1.12509795],
#        [ 0.36401406,  0.7225293 ],
#        [ 0.44170953,  0.79951376],
#        [-1.42298184, -1.04811348],
#        [ 0.36401406,  0.7225293 ],
#        [ 1.06327332,  0.64554483],
#        [-1.42298184, -1.12509795],
#        [-0.6460271 , -0.43223773],
#        [-1.42298184, -1.04811348],
#        [-0.10215878, -0.66319114],
#        [-0.80141805, -0.58620667],
#        [-1.42298184, -1.35605136],
#        [-0.10215878,  0.26062248],
#        [-0.80141805,  0.02966908],
#        [-1.65606826, -1.35605136],
#        [-1.26759089, -0.89414455],
#        [-0.56833163, -0.12429986],
#        [-1.57837279, -1.20208242],
#        [ 0.28631859,  0.10665355],
#        [-0.02446331, -0.81716008],
#        [-1.50067732, -1.12509795],
#        [-1.65606826, -1.35605136],
#        [-0.10215878, -0.74017561],
#        [-0.49063615, -0.12429986],
#        [-0.33524521,  0.10665355],
#        [-1.11219995, -0.89414455],
#        [ 0.20862311,  0.02966908],
#        [-1.34528637, -0.97112901],
#        [-0.25754973,  0.10665355],
#        [ 1.1409688 ,  0.49157589],
#        [-0.17985426,  0.18363801],
#        [-0.41294068, -0.89414455],
#        [ 0.44170953,  0.56856036],
#        [-0.956809  , -0.81716008],
#        [-0.72372258, -0.66319114],
#        [ 0.36401406, -0.2782688 ],
#        [-1.50067732, -1.12509795],
#        [-0.87911352, -0.5092222 ],
#        [-0.33524521, -0.97112901],
#        [-1.11219995, -0.74017561],
#        [ 0.28631859,  0.33760695],
#        [ 0.05323216,  0.41459142],
#        [ 0.8301869 ,  0.9534827 ],
#        [-0.72372258, -0.58620667],
#        [-0.33524521, -0.58620667],
#        [ 0.44170953,  0.79951376],
#        [ 0.20862311,  0.10665355],
#        [-0.02446331, -0.66319114],
#        [ 1.60714164,  0.33760695],
#        [-0.25754973,  0.02966908],
#        [-0.25754973,  0.10665355],
#        [ 1.99561901,  2.72412548],
#        [-1.03450447, -0.81716008],
#        [-1.42298184, -1.04811348],
#        [-1.42298184, -1.04811348],
#        [ 0.90788238,  1.18443611],
#        [ 1.21866427,  0.33760695],
#        [-1.42298184, -1.04811348],
#        [ 1.37405522,  1.72332739],
#        [ 0.44170953, -0.04731539],
#        [-0.41294068, -0.04731539],
#        [-0.25754973, -0.97112901],
#        [-0.10215878, -1.20208242],
#        [ 0.98557785,  1.18443611],
#        [-0.33524521,  0.02966908],
#        [-1.18989542, -1.20208242],
#        [-0.17985426,  0.18363801],
#        [-1.42298184, -1.12509795],
#        [ 1.29635975,  1.64634292],
#        [-0.56833163, -0.81716008],
#        [ 0.28631859,  0.10665355],
#        [-0.87911352, -1.27906689],
#        [-0.49063615, -0.5092222 ],
#        [-0.56833163, -0.5092222 ],
#        [ 0.51940501,  0.33760695],
#        [-0.6460271 , -0.81716008],
#        [-0.72372258, -0.5092222 ],
#        [-0.10215878,  0.26062248],
#        [ 0.05323216, -0.58620667],
#        [-0.72372258, -0.89414455],
#        [ 0.90788238,  0.18363801],
#        [ 1.21866427,  1.33840504],
#        [-0.17985426,  0.18363801],
#        [-1.50067732, -1.27906689],
#        [-1.03450447, -0.81716008],
#        [-0.49063615, -0.5092222 ],
#        [ 1.29635975,  1.56935845],
#        [ 0.51940501,  0.7225293 ],
#        [ 0.28631859,  0.49157589],
#        [ 1.21866427,  0.10665355],
#        [ 1.06327332,  0.10665355],
#        [-1.11219995, -1.12509795],
#        [ 0.44170953, -0.04731539],
#        [ 0.20862311,  0.56856036],
#        [-1.18989542, -0.89414455],
#        [ 1.84022806,  1.72332739],
#        [-0.25754973, -0.89414455],
#        [-1.34528637, -1.12509795],
#        [ 0.67479596,  0.9534827 ],
#        [ 1.21866427,  1.49237398],
#        [ 0.05323216,  0.41459142],
#        [-0.25754973,  0.41459142],
#        [-0.41294068, -0.5092222 ],
#        [ 0.59710048,  0.41459142],
#        [-0.10215878,  0.02966908],
#        [ 0.44170953,  0.41459142],
#        [ 0.51940501, -0.81716008],
#        [ 1.29635975,  1.64634292],
#        [-0.17985426, -0.74017561],
#        [ 0.67479596, -0.43223773],
#        [-1.42298184, -1.20208242],
#        [ 0.44170953, -0.81716008],
#        [-0.80141805, -0.74017561],
#        [-0.02446331,  0.33760695],
#        [ 0.59710048,  0.41459142],
#        [-1.03450447, -1.12509795],
#        [ 0.75249143,  0.9534827 ],
#        [ 1.45175069,  1.18443611],
#        [ 1.76253259,  2.10824973],
#        [ 0.67479596,  0.64554483],
#        [ 0.67479596,  1.03046717],
#        [ 1.1409688 ,  1.33840504],
#        [ 1.06327332,  0.9534827 ],
#        [ 1.60714164,  1.95428079],
#        [-0.6460271 , -0.58620667],
#        [ 1.91792354,  2.03126526],
#        [-0.72372258, -0.81716008],
#        [ 1.52944617,  1.72332739],
#        [ 1.52944617,  0.02966908],
#        [-1.42298184, -1.27906689],
#        [-1.11219995, -1.04811348],
#        [-1.11219995, -1.12509795],
#        [-0.80141805, -0.89414455],
#        [ 2.30640091,  2.33920314],
#        [ 0.67479596,  0.7225293 ],
#        [ 0.13092764,  0.02966908],
#        [ 1.84022806,  2.1852342 ],
#        [ 1.29635975,  1.56935845],
#        [ 1.1409688 ,  0.7225293 ],
#        [ 2.22870543,  2.57015654],
#        [ 1.76253259,  1.95428079],
#        [-1.11219995, -0.89414455],
#        [ 2.07331449,  2.4161876 ],
#        [ 0.44170953,  0.7225293 ],
#        [-1.57837279, -1.35605136],
#        [ 0.51940501,  0.7225293 ],
#        [-1.11219995, -0.97112901],
#        [ 0.8301869 , -0.81716008],
#        [ 0.75249143,  0.79951376],
#        [ 1.29635975, -0.66319114],
#        [-0.87911352, -1.27906689],
#        [-0.25754973, -0.81716008],
#        [ 1.37405522,  1.41538951],
#        [-0.33524521,  0.02966908],
#        [-0.41294068, -0.5092222 ],
#        [ 2.07331449,  1.95428079],
#        [ 1.76253259,  1.64634292],
#        [ 1.29635975,  1.41538951],
#        [ 0.36401406, -0.12429986],
#        [ 0.44170953, -0.35525327],
#        [-0.6460271 , -1.04811348],
#        [ 1.84022806,  2.03126526],
#        [ 0.8301869 ,  1.03046717],
#        [-1.18989542, -1.04811348],
#        [ 0.67479596,  0.79951376],
#        [-1.34528637, -1.35605136],
#        [-0.02446331, -0.20128433],
#        [-0.17985426, -0.81716008],
#        [-0.6460271 , -0.66319114],
#        [ 0.51940501,  0.10665355],
#        [ 0.98557785,  1.33840504],
#        [-0.02446331, -0.89414455],
#        [-1.26759089, -1.12509795],
#        [-0.80141805, -0.66319114],
#        [ 1.84022806,  2.10824973],
#        [-0.49063615, -0.12429986],
#        [-0.49063615, -0.20128433],
#        [ 0.13092764,  0.41459142],
#        [-1.03450447, -0.66319114],
#        [-0.72372258, -0.5092222 ],
#        [ 0.13092764, -0.20128433],
#        [ 0.59710048,  1.03046717],
#        [-1.11219995, -1.04811348],
#        [ 0.05323216, -0.20128433],
#        [ 1.1409688 ,  1.49237398],
#        [-0.956809  , -0.58620667],
#        [ 0.05323216,  0.41459142],
#        [ 2.07331449,  3.26301676],
#        [-0.17985426, -0.66319114],
#        [-0.33524521, -0.58620667],
#        [ 0.8301869 ,  0.10665355],
#        [-0.25754973, -0.89414455],
#        [ 1.06327332,  1.56935845],
#        [ 0.98557785,  0.41459142],
#        [-0.72372258, -0.43223773],
#        [ 0.75249143,  0.56856036],
#        [ 1.1409688 , -0.20128433],
#        [-0.72372258, -0.5092222 ],
#        [-0.41294068, -0.04731539],
#        [ 1.21866427,  1.56935845],
#        [ 0.67479596,  1.03046717],
#        [ 0.75249143,  1.33840504],
#        [-0.56833163, -0.58620667],
#        [ 1.45175069,  0.7225293 ],
#        [ 1.29635975,  1.18443611],
#        [-1.42298184, -1.12509795],
#        [ 0.36401406,  0.79951376],
#        [ 2.6171828 ,  2.4161876 ],
#        [ 1.21866427,  1.56935845],
#        [ 0.28631859,  0.7225293 ],
#        [-0.02446331,  0.18363801],
#        [-1.11219995, -1.27906689],
#        [ 0.20862311,  0.26062248],
#        [ 2.07331449,  1.72332739],
#        [ 1.29635975,  1.33840504],
#        [ 0.44170953, -0.2782688 ],
#        [-0.87911352, -1.04811348],
#        [-0.6460271 , -0.5092222 ],
#        [ 0.05323216, -0.20128433],
#        [ 0.59710048,  0.9534827 ],
#        [-0.17985426, -0.04731539],
#        [ 1.60714164,  1.95428079],
#        [ 1.60714164,  1.72332739],
#        [-0.56833163, -0.58620667],
#        [-0.956809  , -1.27906689],
#        [ 0.98557785,  0.9534827 ],
#        [ 0.8301869 ,  1.03046717],
#        [-0.72372258, -0.74017561],
#        [ 0.05323216,  0.18363801],
#        [-0.80141805, -0.81716008],
#        [ 0.59710048,  0.64554483],
#        [ 0.36401406,  0.10665355],
#        [ 0.44170953,  0.64554483],
#        [-1.42298184, -1.27906689],
#        [-1.26759089, -1.12509795],
#        [ 1.21866427,  1.56935845],
#        [-0.87911352, -0.74017561],
#        [-1.11219995, -1.12509795],
#        [ 0.36401406,  0.41459142],
#        [-1.11219995, -0.97112901],
#        [ 1.68483712,  2.03126526],
#        [ 0.36401406,  0.26062248],
#        [-0.56833163, -0.66319114],
#        [ 0.51940501,  0.7225293 ],
#        [ 0.51940501, -0.20128433],
#        [ 1.21866427,  1.41538951],
#        [ 0.8301869 ,  0.02966908],
#        [ 1.37405522,  0.10665355],
#        [ 0.59710048,  0.10665355],
#        [ 0.8301869 ,  0.9534827 ],
#        [ 0.67479596,  0.10665355],
#        [ 1.52944617,  0.56856036],
#        [ 0.20862311, -0.20128433],
#        [-1.11219995, -1.04811348]])

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size = 0.25, random_state = 49)
y_train.head()
# Out:
# 211    111350
# 93     166024
# 252    132000
# 293    104800
# 326    124714
# Name: salary, dtype: int64

# %%
regression = LinearRegression()
regression.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
data.tail(5)
# Out:
#      yrs.since.phd  yrs.service  salary
# 392             33           30  103106
# 393             31           19  150564
# 394             42           25  101738
# 395             25           15   95329
# 396              8            4   81035

# %%
print('salary :', regression.predict(scaler.transform([[42,25]])))
# Out:
# salary : [136665.0800774]
